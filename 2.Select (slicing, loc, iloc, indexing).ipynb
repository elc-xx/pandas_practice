# %% [markdown]
# # Basic select #

# %%
import pandas as pd
pd.set_option('max_rows', 6)

oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# One column (also known as Series instead of Dataframe)
oo['City']
# same result: oo.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
# Multiple columns by name
oo[['City', 'Sport', 'Event']]
# Out:
#           City      Sport                       Event
# 0       Athens   Aquatics              100m freestyle
# 1       Athens   Aquatics              100m freestyle
# 2       Athens   Aquatics  100m freestyle for sailors
# 3       Athens   Aquatics  100m freestyle for sailors
# 4       Athens   Aquatics  100m freestyle for sailors
# ...        ...        ...                         ...
# 29211  Beijing  Wrestling                   84 - 96kg
# 29212  Beijing  Wrestling                  96 - 120kg
# 29213  Beijing  Wrestling                  96 - 120kg
# 29214  Beijing  Wrestling                  96 - 120kg
# 29215  Beijing  Wrestling                  96 - 120kg
#
# [29216 rows x 3 columns]

# %%
# Add new concatenated column. First parameter is the position (starting from 0)
# Edition is numeric so it has to be casted to string
oo.insert(2, 'City_Edition', oo['City'] + ' ' + oo['Edition'].astype('string'))
oo.head()
# Out:
#      City  Edition City_Edition     Sport Discipline             Athlete  NOC  \
# 0  Athens     1896  Athens 1896  Aquatics   Swimming       HAJOS, Alfred  HUN
# 1  Athens     1896  Athens 1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2  Athens     1896  Athens 1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3  Athens     1896  Athens 1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4  Athens     1896  Athens 1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
# Another way to add a column at the end.
oo['Gold'] = ['Yes' if x =='Gold' else 'No' for x in oo['Medal']]
oo.head()
# Out:
#      City  Edition City_Edition     Sport Discipline             Athlete  NOC  \
# 0  Athens     1896  Athens 1896  Aquatics   Swimming       HAJOS, Alfred  HUN
# 1  Athens     1896  Athens 1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2  Athens     1896  Athens 1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3  Athens     1896  Athens 1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4  Athens     1896  Athens 1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE
#
#   Gender                       Event Event_gender   Medal Gold
# 0    Men              100m freestyle            M    Gold  Yes
# 1    Men              100m freestyle            M  Silver   No
# 2    Men  100m freestyle for sailors            M  Bronze   No
# 3    Men  100m freestyle for sailors            M    Gold  Yes
# 4    Men  100m freestyle for sailors            M  Silver   No

# %%
# Rename column NOC to Country
oo.rename(columns={'NOC':'Country'})
# Out:
#           City  Edition      Sport       Discipline            Athlete  \
# 0       Athens     1896   Aquatics         Swimming      HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming   HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming  DRIVAS, Dimitrios
# ...        ...      ...        ...              ...                ...
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R    PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R      LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R     BAROEV, Khasan
#
#       Country Gender                       Event Event_gender   Medal
# 0         HUN    Men              100m freestyle            M    Gold
# 1         AUT    Men              100m freestyle            M  Silver
# 2         GRE    Men  100m freestyle for sailors            M  Bronze
# ...       ...    ...                         ...          ...     ...
# 29213     ARM    Men                  96 - 120kg            M  Bronze
# 29214     CUB    Men                  96 - 120kg            M    Gold
# 29215     RUS    Men                  96 - 120kg            M  Silver
#
# [29216 rows x 10 columns]

# %%
# Distinct
oo.Sport.unique()
# Out:
# array(['Aquatics', 'Athletics', 'Cycling', 'Fencing', 'Gymnastics',
#        'Shooting', 'Tennis', 'Weightlifting', 'Wrestling', 'Archery',
#        'Basque Pelota', 'Cricket', 'Croquet', 'Equestrian', 'Football',
#        'Golf', 'Polo', 'Rowing', 'Rugby', 'Sailing', 'Tug of War',
#        'Boxing', 'Lacrosse', 'Roque', 'Hockey', 'Jeu de paume', 'Rackets',
#        'Skating', 'Water Motorsports', 'Modern Pentathlon', 'Ice Hockey',
#        'Basketball', 'Canoe / Kayak', 'Handball', 'Judo', 'Volleyball',
#        'Table Tennis', 'Badminton', 'Baseball', 'Softball', 'Taekwondo',
#        'Triathlon'], dtype=object)

# %%
# Count by column
# Number of medals given each Edition
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
# Sort
oo.sort_values('NOC')
# Change to descending: oo.sort_values('NOC', ascending = False)
# Out:
#             City  Edition      Sport Discipline                   Athlete  \
# 28965    Beijing     2008  Taekwondo  Taekwondo          NIKPAI, Rohullah
# 19323      Seoul     1988    Sailing    Sailing           BOERSMA, Jan D.
# 19874  Barcelona     1992  Athletics  Athletics        BOULMERKA, Hassiba
# 21960    Atlanta     1996     Boxing     Boxing           BAHARI, Mohamed
# 21610    Atlanta     1996  Athletics  Athletics       MORCELI, Nourredine
# ...          ...      ...        ...        ...                       ...
# 133       Athens     1896     Tennis     Tennis  ROBERTSON, George Stuart
# 493        Paris     1900     Rowing     Rowing  BRANDT, Francois Antoine
# 132       Athens     1896     Tennis     Tennis              FLACK, Edwin
# 495        Paris     1900     Rowing     Rowing             KLEIN, Roelof
# 864     St Louis     1904    Fencing    Fencing              DIAZ, Manuel
#
#        NOC Gender                                Event Event_gender   Medal
# 28965  AFG    Men                              - 58 kg            M  Bronze
# 19323  AHO    Men                  board (division II)            M  Silver
# 19874  ALG  Women                                1500m            W    Gold
# 21960  ALG    Men                              71-75kg            M  Bronze
# 21610  ALG    Men                                1500m            M    Gold
# ...    ...    ...                                  ...          ...     ...
# 133    ZZX    Men                              doubles            M  Bronze
# 493    ZZX    Men  pair-oared shell with coxswain (2+)            M    Gold
# 132    ZZX    Men                              doubles            M  Bronze
# 495    ZZX    Men  pair-oared shell with coxswain (2+)            M    Gold
# 864    ZZX    Men                            foil team            M    Gold
#
# [29216 rows x 10 columns]

# %% [markdown]
# ## Slicing ##

# %% [markdown]
# Basic form allows to cut specific rows.

# %%
# Reference
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# select first two rows
oo[:2]
# Out:
#      City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming  HERSCHMANN, Otto  AUT    Men
#
#             Event Event_gender   Medal
# 0  100m freestyle            M    Gold
# 1  100m freestyle            M  Silver

# %%
# select rows 3 and 4, not inclusive
oo[3:5]
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# slice specific column
# first 10 values
oo.Athlete.values[:10]
# Out:
# array(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon',
#        'CHOROPHAS, Efstathios', 'HAJOS, Alfred', 'ANDREOU, Joannis',
#        'CHOROPHAS, Efstathios', 'NEUMANN, Paul'], dtype=object)

# %%
# slice full column
oo.Event.values[:]
# Out:
# array(['100m freestyle', '100m freestyle', '100m freestyle for sailors',
#        ..., '96 - 120kg', '96 - 120kg', '96 - 120kg'], dtype=object)

# %% [markdown]
# ## loc and iloc ##

# %% [markdown]
# **loc[]** the function selects the data by labels of rows or columns.
#
# **iloc[ ]** is used for selection based on position. It is similar to loc[] indexer but it takes only integer values to make selections.

# %%
# slicing with loc, inclusive to the last value
oo.loc[3:5]
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
#
#                         Event Event_gender   Medal
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver
# 5             1200m freestyle            M  Bronze

# %%
# get specific value based on row (index) and colum
oo.loc[4, 'Athlete']
# Out:
# 'CHASAPIS, Spiridon'

# %%
# same as previous but with iloc to use numeric notation
oo.iloc[4,4]
# Out:
# 'CHASAPIS, Spiridon'

# %%
# select specific row with iloc
oo.iloc[3]
# Out:
# City                                Athens
# Edition                               1896
# Sport                             Aquatics
# Discipline                        Swimming
# Athlete                 MALOKINIS, Ioannis
# NOC                                    GRE
# Gender                                 Men
# Event           100m freestyle for sailors
# Event_gender                             M
# Medal                                 Gold
# Name: 3, dtype: object

# %%
# select all the rows for specific columns
oo.iloc[:, [2, 3, 5]]
# Out:
#            Sport       Discipline  NOC
# 0       Aquatics         Swimming  HUN
# 1       Aquatics         Swimming  AUT
# 2       Aquatics         Swimming  GRE
# 3       Aquatics         Swimming  GRE
# 4       Aquatics         Swimming  GRE
# ...          ...              ...  ...
# 29211  Wrestling  Wrestling Gre-R  GER
# 29212  Wrestling  Wrestling Gre-R  LTU
# 29213  Wrestling  Wrestling Gre-R  ARM
# 29214  Wrestling  Wrestling Gre-R  CUB
# 29215  Wrestling  Wrestling Gre-R  RUS
#
# [29216 rows x 3 columns]

# %% [markdown]
# ## Indexing ##

# %% [markdown]
# Like a dict, a DataFrame's index is backed by a hash table. Looking up rows based on index values is like looking up dict values based on a key. Looking up rows based on index values is faster than looking up rows based on column values.
#
#
# Note however, it takes time to build the index. So having the index is only advantageous when you have many lookups of this type to perform.

# %%
# Default index is a consecutive, bold column in the left
oo.index
# Out:
# RangeIndex(start=0, stop=29216, step=1)

# %%
# set new index, recommended to always create a new data frame for changes
oo_by_edition = oo.set_index("Edition")
oo_by_edition.index

# remove new index with reset_index()
# Out:
# Int64Index([1896, 1896, 1896, 1896, 1896, 1896, 1896, 1896, 1896, 1896,
#             ...
#             2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008],
#            dtype='int64', name='Edition', length=29216)

# %%
# bold column in the left
oo_by_edition.head()
# Out:
#            City     Sport Discipline             Athlete  NOC Gender  \
# Edition
# 1896     Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1896     Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 1896     Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 1896     Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 1896     Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                               Event Event_gender   Medal
# Edition
# 1896                 100m freestyle            M    Gold
# 1896                 100m freestyle            M  Silver
# 1896     100m freestyle for sailors            M  Bronze
# 1896     100m freestyle for sailors            M    Gold
# 1896     100m freestyle for sailors            M  Silver

# %%
# slice with loc
oo_by_edition.loc[1950:2000]
# Out:
#              City      Sport       Discipline                 Athlete  NOC  \
# Edition
# 1952     Helsinki   Aquatics           Diving          HAASE, Günther  GER
# 1952     Helsinki   Aquatics           Diving             LEE, Samuel  USA
# 1952     Helsinki   Aquatics           Diving  CAPILLA PEREZ, Joaquin  MEX
# ...           ...        ...              ...                     ...  ...
# 2000       Sydney  Wrestling  Wrestling Gre-R         DEBELKA, Dmitry  BLR
# 2000       Sydney  Wrestling  Wrestling Gre-R          GARDNER, Rulon  USA
# 2000       Sydney  Wrestling  Wrestling Gre-R      KARELIN, Aleksandr  RUS
#
#         Gender         Event Event_gender   Medal
# Edition
# 1952       Men  10m platform            M  Bronze
# 1952       Men  10m platform            M    Gold
# 1952       Men  10m platform            M  Silver
# ...        ...           ...          ...     ...
# 2000       Men    97 - 130kg            M  Bronze
# 2000       Men    97 - 130kg            M    Gold
# 2000       Men    97 - 130kg            M  Silver
#
# [17158 rows x 9 columns]

# %%
# slice with iloc
oo_by_edition.iloc[0:10]
# Out:
#            City     Sport Discipline                Athlete  NOC Gender  \
# Edition
# 1896     Athens  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1896     Athens  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 1896     Athens  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# ...         ...       ...        ...                    ...  ...    ...
# 1896     Athens  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 1896     Athens  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 1896     Athens  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                               Event Event_gender   Medal
# Edition
# 1896                 100m freestyle            M    Gold
# 1896                 100m freestyle            M  Silver
# 1896     100m freestyle for sailors            M  Bronze
# ...                             ...          ...     ...
# 1896                1200m freestyle            M  Silver
# 1896                 400m freestyle            M  Bronze
# 1896                 400m freestyle            M    Gold
#
# [10 rows x 9 columns]

# %%
# sort an index
oo_by_sport = oo.set_index("Sport").sort_index()
oo_by_sport
# Out:
#                   City  Edition       Discipline                    Athlete  \
# Sport
# Aquatics        Athens     1896         Swimming              HAJOS, Alfred
# Aquatics        London     1948         Swimming  ZIMMERMAN, Suzanne Winona
# Aquatics        London     1948         Swimming     HARUP, Karen Margrethe
# ...                ...      ...              ...                        ...
# Wrestling  Los Angeles     1984  Wrestling Gre-R       JOHANSSON, Kent-Olle
# Wrestling     Helsinki     1952  Wrestling Gre-R      GRÖNDAHL, Kelpo Olavi
# Wrestling      Beijing     2008  Wrestling Gre-R             BAROEV, Khasan
#
#            NOC Gender                          Event Event_gender   Medal
# Sport
# Aquatics   HUN    Men                 100m freestyle            M    Gold
# Aquatics   USA  Women                100m backstroke            W  Silver
# Aquatics   DEN  Women                100m backstroke            W    Gold
# ...        ...    ...                            ...          ...     ...
# Wrestling  SWE    Men      57 - 62kg (featherweight)            M  Silver
# Wrestling  FIN    Men  79 - 87kg (light-heavyweight)            M    Gold
# Wrestling  RUS    Men                     96 - 120kg            M  Silver
#
# [29216 rows x 9 columns]

# %%
oo_by_sport.loc['Football']
# Out:
#                City  Edition Discipline             Athlete  NOC Gender  \
# Sport
# Football  Amsterdam     1928   Football   CANAVESI, Adhemar  URU    Men
# Football  Amsterdam     1928   Football      CASTRO, Hector  URU    Men
# Football  Amsterdam     1928   Football    SCHIAVIO, Angelo  ITA    Men
# ...             ...      ...        ...                 ...  ...    ...
# Football   Montreal     1976   Football   WIECZOREK, Henryk  POL    Men
# Football     London     1948   Football  JOVANOVIC, Miodrag  YUG    Men
# Football   Montreal     1976   Football    ZMUDA, Wladyslaw  POL    Men
#
#              Event Event_gender   Medal
# Sport
# Football  football            M    Gold
# Football  football            M    Gold
# Football  football            M  Bronze
# ...            ...          ...     ...
# Football  football            M  Silver
# Football  football            M  Silver
# Football  football            M  Silver
#
# [1387 rows x 9 columns]

# %%
# we can define multiple indexes
oo_multi = oo.set_index(['Edition','NOC'])
oo_multi
# Out:
#                 City      Sport       Discipline            Athlete Gender  \
# Edition NOC
# 1896    HUN   Athens   Aquatics         Swimming      HAJOS, Alfred    Men
#         AUT   Athens   Aquatics         Swimming   HERSCHMANN, Otto    Men
#         GRE   Athens   Aquatics         Swimming  DRIVAS, Dimitrios    Men
# ...              ...        ...              ...                ...    ...
# 2008    ARM  Beijing  Wrestling  Wrestling Gre-R    PATRIKEEV, Yuri    Men
#         CUB  Beijing  Wrestling  Wrestling Gre-R      LOPEZ, Mijain    Men
#         RUS  Beijing  Wrestling  Wrestling Gre-R     BAROEV, Khasan    Men
#
#                                   Event Event_gender   Medal
# Edition NOC
# 1896    HUN              100m freestyle            M    Gold
#         AUT              100m freestyle            M  Silver
#         GRE  100m freestyle for sailors            M  Bronze
# ...                                 ...          ...     ...
# 2008    ARM                  96 - 120kg            M  Bronze
#         CUB                  96 - 120kg            M    Gold
#         RUS                  96 - 120kg            M  Silver
#
# [29216 rows x 8 columns]
